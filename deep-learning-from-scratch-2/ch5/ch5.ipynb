# %%
import numpy as np

class RNN(object):
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
        
    def forward(self, x, h_prev):
        Wx, Wh, b = self.params
        t = np.dot(h_prev, Wh) + np.dot(x, Wx) + b
        h_next = np.tanh(t)
        
        self.cache = (x, h_prev, h_next)
        return h_next
    
    def backward(self, dh_next):
        Wx, Wh, b = self.params
        x, h_prev, h_next = self.cache
        
        dt = dh_next * (1 - h_next ** 2)
        db = np.sum(dt, axis=0)
        dWh = np.dot(h_prev.T, dt)
        dh_prev = np.dot(dt, Wh.T)
        dWx = np.dot(x.T, dt)
        dx = np.dot(dt, Wx.T)
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dx, dh_prev

# %%
class TimeRNN(object):
    def __init__(self, Wx, Wh, b, statefule=False):
        self.params = [Wx, Wh]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        self.h, self.dh = None, None
        self.statefule = statefule
        
    def state(self, h):
        self.h = h
    
    def reset_state(self):
        self.h = None
    
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, B = xs.shape
        D, H = Wx.shape
        
        self.layers = []
        hs = np.empty((N, T, H), dtype='f')
        
        if not self.stateful or self.h in None:
            self.h = np.zeros((N, H), dtype='f')
        
        for i in range(T):
            layer = RNN(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            self.layers.append(layer)
        
        return hs
    
    def backward(self, shs):
        Wx, Wh, b = self.params
        N, T, H = xs.shape
        D, H = Wx.shape
        
        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx
            
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
                
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
            
        self.dh = dh
        
        return dxs

# %%
import sys
sys.path.append('..')
import numpy as np
from common.time_layers import *


class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 重みの初期化
        embed_W = (rn(V, D) / 100).astype('f')
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        rnn_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # レイヤの生成
        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]

        # すべての重みと勾配をリストにまとめる
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
import sys
sys.path.append('..')
sys.path.append('../author_code/ch05')
import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import SGD
from dataset import ptb
from simple_rnnlm import SimpleRnnlm


# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5  # Truncated BPTTの展開する時間サイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み（データセットを小さくする）
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）
data_size = len(xs)
print('corpus size: %d, vocabulary size: %d' % (corpus_size, vocab_size))

# 学習時に使用する変数
max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

# ミニバッチの各サンプルの読み込み開始位置を計算
jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        # ミニバッチの取得
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1

        # 勾配を求め、パラメータを更新
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1

    # エポックごとにパープレキシティの評価
    ppl = np.exp(total_loss / loss_count)
    print('| epoch %d | perplexity %.2f'
          % (epoch+1, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0

# グラフの描画
x = np.arange(len(ppl_list))
plt.plot(x, ppl_list, label='train')
plt.xlabel('epochs')
plt.ylabel('perplexity')
plt.show()
# Out:
# corpus size: 1000, vocabulary size: 418
# | epoch 1 | perplexity 381.39
# | epoch 2 | perplexity 243.55
# | epoch 3 | perplexity 217.30
# | epoch 4 | perplexity 211.38
# | epoch 5 | perplexity 202.83
# | epoch 6 | perplexity 200.53
# | epoch 7 | perplexity 197.17
# | epoch 8 | perplexity 195.62
# | epoch 9 | perplexity 190.03
# | epoch 10 | perplexity 191.70
# | epoch 11 | perplexity 188.28
# | epoch 12 | perplexity 192.36
# | epoch 13 | perplexity 189.05
# | epoch 14 | perplexity 190.03
# | epoch 15 | perplexity 188.64
# | epoch 16 | perplexity 185.58
# | epoch 17 | perplexity 183.82
# | epoch 18 | perplexity 180.17
# | epoch 19 | perplexity 180.94
# | epoch 20 | perplexity 183.05
# | epoch 21 | perplexity 181.17
# | epoch 22 | perplexity 176.38
# | epoch 23 | perplexity 174.41
# | epoch 24 | perplexity 177.82
# | epoch 25 | perplexity 172.87
# | epoch 26 | perplexity 172.55
# | epoch 27 | perplexity 167.65
# | epoch 28 | perplexity 168.05
# | epoch 29 | perplexity 163.69
# | epoch 30 | perplexity 159.13
# | epoch 31 | perplexity 158.08
# | epoch 32 | perplexity 153.51
# | epoch 33 | perplexity 150.23
# | epoch 34 | perplexity 147.97
# | epoch 35 | perplexity 146.12
# | epoch 36 | perplexity 139.25
# | epoch 37 | perplexity 135.13
# | epoch 38 | perplexity 130.94
# | epoch 39 | perplexity 126.02
# | epoch 40 | perplexity 124.46
# | epoch 41 | perplexity 122.64
# | epoch 42 | perplexity 115.65
# | epoch 43 | perplexity 111.15
# | epoch 44 | perplexity 105.82
# | epoch 45 | perplexity 103.82
# | epoch 46 | perplexity 105.30
# | epoch 47 | perplexity 96.36
# | epoch 48 | perplexity 92.74
# | epoch 49 | perplexity 88.00
# | epoch 50 | perplexity 85.21
# | epoch 51 | perplexity 80.01
# | epoch 52 | perplexity 78.56
# | epoch 53 | perplexity 71.84
# | epoch 54 | perplexity 71.29
# | epoch 55 | perplexity 67.89
# | epoch 56 | perplexity 64.08
# | epoch 57 | perplexity 61.20
# | epoch 58 | perplexity 56.95
# | epoch 59 | perplexity 55.86
# | epoch 60 | perplexity 51.87
# | epoch 61 | perplexity 50.18
# | epoch 62 | perplexity 47.29
# | epoch 63 | perplexity 43.42
# | epoch 64 | perplexity 41.75
# | epoch 65 | perplexity 41.25
# | epoch 66 | perplexity 38.04
# | epoch 67 | perplexity 35.78
# | epoch 68 | perplexity 33.51
# | epoch 69 | perplexity 31.74
# | epoch 70 | perplexity 31.03
# | epoch 71 | perplexity 30.01
# | epoch 72 | perplexity 27.22
# | epoch 73 | perplexity 26.27
# | epoch 74 | perplexity 24.95
# | epoch 75 | perplexity 23.51
# | epoch 76 | perplexity 22.66
# | epoch 77 | perplexity 20.72
# | epoch 78 | perplexity 19.27
# | epoch 79 | perplexity 18.22
# | epoch 80 | perplexity 17.30
# | epoch 81 | perplexity 16.84
# | epoch 82 | perplexity 15.94
# | epoch 83 | perplexity 15.06
# | epoch 84 | perplexity 13.93
# | epoch 85 | perplexity 13.84
# | epoch 86 | perplexity 12.73
# | epoch 87 | perplexity 12.28
# | epoch 88 | perplexity 11.16
# | epoch 89 | perplexity 10.55
# | epoch 90 | perplexity 10.08
# | epoch 91 | perplexity 9.46
# | epoch 92 | perplexity 9.37
# | epoch 93 | perplexity 8.77
# | epoch 94 | perplexity 8.68
# | epoch 95 | perplexity 8.04
# | epoch 96 | perplexity 7.52
# | epoch 97 | perplexity 7.30
# | epoch 98 | perplexity 6.95
# | epoch 99 | perplexity 6.51
# | epoch 100 | perplexity 6.64

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from dataset import ptb
from simple_rnnlm import SimpleRnnlm


# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100  # RNNの隠れ状態ベクトルの要素数
time_size = 5  # RNNを展開するサイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000  # テスト用にデータセットを小さくする
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)
xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size)
trainer.plot()
# Out:
# | epoch 1 |  iter 1 / 19 | time 0[s] | perplexity 416.89
# | epoch 2 |  iter 1 / 19 | time 0[s] | perplexity 380.79
# | epoch 3 |  iter 1 / 19 | time 0[s] | perplexity 261.14
# | epoch 4 |  iter 1 / 19 | time 0[s] | perplexity 218.94
# | epoch 5 |  iter 1 / 19 | time 0[s] | perplexity 209.69
# | epoch 6 |  iter 1 / 19 | time 0[s] | perplexity 208.06
# | epoch 7 |  iter 1 / 19 | time 0[s] | perplexity 200.45
# | epoch 8 |  iter 1 / 19 | time 0[s] | perplexity 200.69
# | epoch 9 |  iter 1 / 19 | time 0[s] | perplexity 195.56
# | epoch 10 |  iter 1 / 19 | time 0[s] | perplexity 190.96
# | epoch 11 |  iter 1 / 19 | time 0[s] | perplexity 192.88
# | epoch 12 |  iter 1 / 19 | time 0[s] | perplexity 189.31
# | epoch 13 |  iter 1 / 19 | time 0[s] | perplexity 193.58
# | epoch 14 |  iter 1 / 19 | time 0[s] | perplexity 188.82
# | epoch 15 |  iter 1 / 19 | time 0[s] | perplexity 188.46
# | epoch 16 |  iter 1 / 19 | time 0[s] | perplexity 192.72
# | epoch 17 |  iter 1 / 19 | time 0[s] | perplexity 191.16
# | epoch 18 |  iter 1 / 19 | time 0[s] | perplexity 186.91
# | epoch 19 |  iter 1 / 19 | time 0[s] | perplexity 183.47
# | epoch 20 |  iter 1 / 19 | time 0[s] | perplexity 183.50
# | epoch 21 |  iter 1 / 19 | time 0[s] | perplexity 180.95
# | epoch 22 |  iter 1 / 19 | time 0[s] | perplexity 180.42
# | epoch 23 |  iter 1 / 19 | time 0[s] | perplexity 182.05
# | epoch 24 |  iter 1 / 19 | time 0[s] | perplexity 180.29
# | epoch 25 |  iter 1 / 19 | time 0[s] | perplexity 173.91
# | epoch 26 |  iter 1 / 19 | time 0[s] | perplexity 176.02
# | epoch 27 |  iter 1 / 19 | time 1[s] | perplexity 174.05
# | epoch 28 |  iter 1 / 19 | time 1[s] | perplexity 174.03
# | epoch 29 |  iter 1 / 19 | time 1[s] | perplexity 167.95
# | epoch 30 |  iter 1 / 19 | time 1[s] | perplexity 164.38
# | epoch 31 |  iter 1 / 19 | time 1[s] | perplexity 162.68
# | epoch 32 |  iter 1 / 19 | time 1[s] | perplexity 158.21
# | epoch 33 |  iter 1 / 19 | time 1[s] | perplexity 157.39
# | epoch 34 |  iter 1 / 19 | time 1[s] | perplexity 156.94
# | epoch 35 |  iter 1 / 19 | time 1[s] | perplexity 150.04
# | epoch 36 |  iter 1 / 19 | time 1[s] | perplexity 147.28
# | epoch 37 |  iter 1 / 19 | time 1[s] | perplexity 148.22
# | epoch 38 |  iter 1 / 19 | time 1[s] | perplexity 140.23
# | epoch 39 |  iter 1 / 19 | time 1[s] | perplexity 137.00
# | epoch 40 |  iter 1 / 19 | time 1[s] | perplexity 132.05
# | epoch 41 |  iter 1 / 19 | time 1[s] | perplexity 127.59
# | epoch 42 |  iter 1 / 19 | time 1[s] | perplexity 127.95
# | epoch 43 |  iter 1 / 19 | time 1[s] | perplexity 123.41
# | epoch 44 |  iter 1 / 19 | time 1[s] | perplexity 119.53
# | epoch 45 |  iter 1 / 19 | time 1[s] | perplexity 110.71
# | epoch 46 |  iter 1 / 19 | time 1[s] | perplexity 108.68
# | epoch 47 |  iter 1 / 19 | time 1[s] | perplexity 107.57
# | epoch 48 |  iter 1 / 19 | time 1[s] | perplexity 102.63
# | epoch 49 |  iter 1 / 19 | time 1[s] | perplexity 99.97
# | epoch 50 |  iter 1 / 19 | time 1[s] | perplexity 92.08
# | epoch 51 |  iter 1 / 19 | time 1[s] | perplexity 88.37
# | epoch 52 |  iter 1 / 19 | time 1[s] | perplexity 84.31
# | epoch 53 |  iter 1 / 19 | time 2[s] | perplexity 82.16
# | epoch 54 |  iter 1 / 19 | time 2[s] | perplexity 77.39
# | epoch 55 |  iter 1 / 19 | time 2[s] | perplexity 74.57
# | epoch 56 |  iter 1 / 19 | time 2[s] | perplexity 70.39
# | epoch 57 |  iter 1 / 19 | time 2[s] | perplexity 68.75
# | epoch 58 |  iter 1 / 19 | time 2[s] | perplexity 64.31
# | epoch 59 |  iter 1 / 19 | time 2[s] | perplexity 61.62
# | epoch 60 |  iter 1 / 19 | time 2[s] | perplexity 56.25
# | epoch 61 |  iter 1 / 19 | time 2[s] | perplexity 52.69
# | epoch 62 |  iter 1 / 19 | time 2[s] | perplexity 50.59
# | epoch 63 |  iter 1 / 19 | time 2[s] | perplexity 48.98
# | epoch 64 |  iter 1 / 19 | time 2[s] | perplexity 46.13
# | epoch 65 |  iter 1 / 19 | time 2[s] | perplexity 43.09
# | epoch 66 |  iter 1 / 19 | time 2[s] | perplexity 40.48
# | epoch 67 |  iter 1 / 19 | time 2[s] | perplexity 37.78
# | epoch 68 |  iter 1 / 19 | time 2[s] | perplexity 37.25
# | epoch 69 |  iter 1 / 19 | time 2[s] | perplexity 34.61
# | epoch 70 |  iter 1 / 19 | time 2[s] | perplexity 31.87
# | epoch 71 |  iter 1 / 19 | time 2[s] | perplexity 29.95
# | epoch 72 |  iter 1 / 19 | time 2[s] | perplexity 28.41
# | epoch 73 |  iter 1 / 19 | time 2[s] | perplexity 27.14
# | epoch 74 |  iter 1 / 19 | time 2[s] | perplexity 25.35
# | epoch 75 |  iter 1 / 19 | time 2[s] | perplexity 23.74
# | epoch 76 |  iter 1 / 19 | time 2[s] | perplexity 22.71
# | epoch 77 |  iter 1 / 19 | time 2[s] | perplexity 21.27
# | epoch 78 |  iter 1 / 19 | time 2[s] | perplexity 20.11
# | epoch 79 |  iter 1 / 19 | time 2[s] | perplexity 18.67
# | epoch 80 |  iter 1 / 19 | time 2[s] | perplexity 17.54
# | epoch 81 |  iter 1 / 19 | time 3[s] | perplexity 16.56
# | epoch 82 |  iter 1 / 19 | time 3[s] | perplexity 16.05
# | epoch 83 |  iter 1 / 19 | time 3[s] | perplexity 14.74
# | epoch 84 |  iter 1 / 19 | time 3[s] | perplexity 13.99
# | epoch 85 |  iter 1 / 19 | time 3[s] | perplexity 13.03
# | epoch 86 |  iter 1 / 19 | time 3[s] | perplexity 12.49
# | epoch 87 |  iter 1 / 19 | time 3[s] | perplexity 11.92
# | epoch 88 |  iter 1 / 19 | time 3[s] | perplexity 11.00
# | epoch 89 |  iter 1 / 19 | time 3[s] | perplexity 10.87
# | epoch 90 |  iter 1 / 19 | time 3[s] | perplexity 9.94
# | epoch 91 |  iter 1 / 19 | time 3[s] | perplexity 9.29
# | epoch 92 |  iter 1 / 19 | time 3[s] | perplexity 8.85
# | epoch 93 |  iter 1 / 19 | time 3[s] | perplexity 8.64
# | epoch 94 |  iter 1 / 19 | time 3[s] | perplexity 8.14
# | epoch 95 |  iter 1 / 19 | time 3[s] | perplexity 7.57
# | epoch 96 |  iter 1 / 19 | time 3[s] | perplexity 7.46
# | epoch 97 |  iter 1 / 19 | time 3[s] | perplexity 7.25
# | epoch 98 |  iter 1 / 19 | time 3[s] | perplexity 7.14
# | epoch 99 |  iter 1 / 19 | time 3[s] | perplexity 6.35
# | epoch 100 |  iter 1 / 19 | time 3[s] | perplexity 6.50
