# %%
# !python ../author_code/chap09/kickstarter_clawler.py
# Out:
# 16 progress 12 / 45073 0.03 %
# 16 progress 24 / 45073 0.05 %
# 16 progress 36 / 45073 0.08 %
# 16 progress 48 / 45073 0.11 %
# 16 progress 60 / 45073 0.13 %
# 16 progress 72 / 45073 0.16 %
# 16 progress 84 / 45073 0.19 %
# 16 progress 96 / 45073 0.21 %
# 16 progress 108 / 45073 0.24 %
# 16 progress 120 / 45073 0.27 %
# 16 progress 132 / 45073 0.29 %
# 16 progress 144 / 45073 0.32 %
# 16 progress 156 / 45073 0.35 %
# 16 progress 168 / 45073 0.37 %
# 16 progress 180 / 45073 0.4 %
# 16 progress 192 / 45073 0.43 %
# 16 progress 204 / 45073 0.45 %
# 16 progress 216 / 45073 0.48 %
# 16 progress 228 / 45073 0.51 %
# 16 progress 240 / 45073 0.53 %
# 16 progress 252 / 45073 0.56 %
# 16 progress 264 / 45073 0.59 %
# 16 progress 276 / 45073 0.61 %
# 16 progress 288 / 45073 0.64 %
# 16 progress 300 / 45073 0.67 %
# 16 progress 312 / 45073 0.69 %
# 16 progress 324 / 45073 0.72 %
# 16 progress 336 / 45073 0.75 %
# 16 progress 348 / 45073 0.77 %
# 16 progress 360 / 45073 0.8 %
# ...

# %%
# !python ../author_code/chap09/kickstarter_result_to_csv.py
# Out:
# ../author_code/chap09/kickstarter_result_to_csv.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = pandas.io.json.json_normalize(project_list)

# %%
import pandas as pd
pd.read_csv("kickstarter_result.csv")
# Out:
#       Unnamed: 0  backers_count  \
# 0              0             10
# 1              1             17
# 2              2              2
# 3              3             64
# 4              4              7
# ...          ...            ...
# 2029        2029            348
# 2030        2030              5
# 2031        2031             29
# 2032        2032             54
# 2033        2033             22
#
#                                                   blurb  \
# 0     Learn how to source materials and equipment, L...
# 1     Kafmasino One combines a home coffee machine w...
# 2     Organize and display your virtual collection o...
# 3     La mejor aplicacin para hacer divisin de cuent...
# 4     A dual port USB in-vehicle device charger that...
# ...                                                 ...
# 2029  It can sensor the surrounding temperature and ...
# 2030  A comprehensive and life-changing digital tool...
# 2031  A comprehensive mobile app to categorize Star ...
# ...
